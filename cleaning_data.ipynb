# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('laptop_data.csv',encoding='latin1')

# %%
df
# Out:
#                                                  Title  \
# 0    AXL Intel Celeron Dual Core 9th Gen - (4 GB/25...
# 1    Lenovo V15 AMD Ryzen 3 Quad Core 7320U - (8 GB...
# 2    ASUS Vivobook 15 Intel Core i3 11th Gen 1115G4...
# 3    MSI Modern 14 Intel Core i5 12th Gen 1235U - (...
# 4    HP 255 G9 AMD Ryzen 3 Dual Core R3 3250 - (8 G...
# ..                                                 ...
# 955  Acer Chromebook Intel Celeron Dual Core N4000 ...
# 956  DELL AMD Ryzen 7 Octa Core AMD R7-6800H - (16 ...
# 957  HP Omen Intel Core i7 13th Gen 13700HX - (16 G...
# 958  Acer Aspire Lite Intel Core i3 11th Gen 1115G4...
# 959  HP Pavilion x360 Intel Core i5 12th Gen 1235U ...
#
#                                        Processor              Ram  \
# 0    Intel Celeron Dual Core Processor (9th Gen)    4 GB DDR4 RAM
# 1                AMD Ryzen 3 Quad Core Processor  8 GB LPDDR5 RAM
# 2             Intel Core i3 Processor (11th Gen)    8 GB DDR4 RAM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           960 non-null    object
#  1   Processor       960 non-null    object
#  2   Ram             960 non-null    object
#  3   OS              960 non-null    object
#  4   Storage         960 non-null    object
#  5   Display         959 non-null    object
#  6   Warranty        915 non-null    object
#  7   Discount Price  960 non-null    object
#  8   Original Price  951 non-null    object
#  9   Delivery        958 non-null    object
#  10  Note            958 non-null    object
#  11  Offer           666 non-null    object
#  12  Reviews         795 non-null    object
# dtypes: object(13)
# memory usage: 97.6+ KB

# %%
df['OS'] = df['OS'].apply(lambda x: x.replace('Operating System',''))

df['OS'] = df['OS'].apply(lambda x: x.replace('64 bit','').strip())

# %%
df.head()
# Out:
#                                                Title  \
# 0  AXL Intel Celeron Dual Core 9th Gen - (4 GB/25...
# 1  Lenovo V15 AMD Ryzen 3 Quad Core 7320U - (8 GB...
# 2  ASUS Vivobook 15 Intel Core i3 11th Gen 1115G4...
# 3  MSI Modern 14 Intel Core i5 12th Gen 1235U - (...
# 4  HP 255 G9 AMD Ryzen 3 Dual Core R3 3250 - (8 G...
#
#                                      Processor              Ram          OS  \
# 0  Intel Celeron Dual Core Processor (9th Gen)    4 GB DDR4 RAM  Windows 11
# 1              AMD Ryzen 3 Quad Core Processor  8 GB LPDDR5 RAM  Windows 11
# 2           Intel Core i3 Processor (11th Gen)    8 GB DDR4 RAM  Windows 11
# 3           Intel Core i5 Processor (12th Gen)   16 GB DDR4 RAM  Windows 11
# 4              AMD Ryzen 3 Dual Core Processor    8 GB DDR4 RAM  Windows 11
#
#       Storage                       Display                       Warranty  \
# 0  256 GB SSD  39.62 cm (15.6 inch) Display                         1 Year
# ...

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8 GB DDR4 RAM                                       327
# 16 GB DDR4 RAM                                      202
# 16 GB DDR5 RAM                                       86
# 16 GB LPDDR5 RAM                                     52
# 4 GB DDR4 RAM                                        51
# 8 GB LPDDR5 RAM                                      40
# 16 GB LPDDR4X RAM                                    31
# 8 GB LPDDR4X RAM                                     26
# 16 GB LPDDR5X RAM                                    23
# 8 GB DDR5 RAM                                        19
# 8 GB Unified Memory RAM                              15
# 4 GB LPDDR4 RAM                                      13
# 32 GB LPDDR5X RAM                                    10
# 4 GB LPDDR4X RAM                                      9
# 32 GB LPDDR5 RAM                                      6
# 32 GB DDR5 RAM                                        5
# 36 GB Unified Memory RAM                              5
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Processor', 'Ram', 'OS', 'Storage', 'Display', 'Warranty',
#        'Discount Price', 'Original Price', 'Delivery', 'Note', 'Offer',
#        'Reviews'],
#       dtype='object')

# %%
df['Storage'] = df['Storage'].apply(lambda x: np.nan if x not in ('256 GB SSD', '512 GB SSD', '1 TB HDD|256 GB SSD', '1 TB SSD') else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           960 non-null    object
#  1   Processor       960 non-null    object
#  2   Ram             960 non-null    object
#  3   OS              960 non-null    object
#  4   Storage         895 non-null    object
#  5   Display         959 non-null    object
#  6   Warranty        915 non-null    object
#  7   Discount Price  960 non-null    object
#  8   Original Price  951 non-null    object
#  9   Delivery        958 non-null    object
#  10  Note            958 non-null    object
#  11  Offer           666 non-null    object
#  12  Reviews         795 non-null    object
# dtypes: object(13)
# memory usage: 97.6+ KB

# %%
extra =  ["Ports: USB 3.2 Gen 1 (x2), USB2.0 (x1), HDMI 1.4, SD Media Card Reader (SD, SDHC, SDXC),RJ45 - 10/100Mbps" ,
'System Diagnosis (All Models), Splendid (All models), Tru2Life (Intel Platform Models), Link to MyASUS (All Models, Bluetooth Needed)',
'43.18 cm (17 inch) Display','38.1 cm (15 inch) Touchscreen Display',
'Ports: 2 USB 3.2 Gen 1 ports, 1 USB 2.0 port, 1 Headset jack, 1 HDMI 1.4 port*,1 Flip-Down RJ-45 port 10/100/1000 Mbps, 1 SD 3.0 card slot',
'1 Year International Travelers Warranty (ITW)','Intel Core i3 Processor (12th Gen)', '1 Year onsite warranty',
 '1 TB SSD','256 GB SSD','Intel Core i7 Processor (12th Gen)','1 Year Onsite warranty', '1 Year Onsite Warranty',
 'Intel Core i5 Processor (12th Gen)','1 Year Carry-in Warranty','1 TB HDD|256 GB SSD']
# df['Display'].apply(lambda x: x if x not in extra else np.nan).value_counts()
df[df['Display'].apply(lambda x:x in extra)]
# Out:
#                                                  Title  \
# 51   HP 360 Intel Celeron Quad Core N4120 - (4 GB/6...
# 90   HP 360 Intel Celeron Dual Core N4120 - (4 GB/6...
# 99   DELL Intel Core i5 12th Gen 1235U - (8 GB/512 ...
# 105  HP Chromebook (2024) MediaTek MT8183 - (4 GB/3...
# 110  Ultimus Intel Celeron Dual Core - (4 GB/128 GB...
# 111  Acer Intel Celeron Dual Core N4500 - (8 GB/128...
# 118  DELL Inspiron Intel Core i7 12th Gen 1255U - (...
# 165  DELL Inspiron Intel Core i7 12th Gen 1255U - (...
# 170  HP 14a Intel Celeron Dual Core N4500 - (4 GB/6...
# 223  ASUS Chromebook Intel Celeron Dual Core N4500 ...
# 283  Acer Intel Celeron Dual Core N4500 - (8 GB/64 ...
# 329  DELL Intel Core i5 12th Gen 1235U - (8 GB/512 ...
# 357  DELL Intel Core i3 12th Gen 1215U - (8 GB/512 ...
# 360  ASUS Chromebook Intel Celeron Dual Core N4020 ...
# 373  ASUS ROG Intel Core i7 7th Gen 7700HQ - (8 GB/...
# 400  ASUS Chromebook Intel Celeron Dual Core N4500 ...
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Processor', 'Ram', 'OS', 'Storage', 'Display', 'Warranty',
#        'Discount Price', 'Original Price', 'Delivery', 'Note', 'Offer',
#        'Reviews'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           960 non-null    object
#  1   Processor       960 non-null    object
#  2   Ram             960 non-null    object
#  3   OS              960 non-null    object
#  4   Storage         895 non-null    object
#  5   Display         959 non-null    object
#  6   Warranty        915 non-null    object
#  7   Discount Price  960 non-null    object
#  8   Original Price  951 non-null    object
#  9   Delivery        958 non-null    object
#  10  Note            958 non-null    object
#  11  Offer           666 non-null    object
#  12  Reviews         795 non-null    object
# dtypes: object(13)
# memory usage: 97.6+ KB

# %%
df['Discount Price'] = df['Discount Price'].apply(lambda x: x.replace('?','').replace(',','')).astype(float)
df['Original Price'] = df['Original Price'].fillna('0').apply(lambda x: x.replace('?','').replace(',','')).astype(float)

# %%
df.columns
# Out:
# Index(['Title', 'Processor', 'Ram', 'OS', 'Storage', 'Display', 'Warranty',
#        'Discount Price', 'Original Price', 'Delivery', 'Note', 'Offer',
#        'Reviews'],
#       dtype='object')

# %%
df['Note'].value_counts()
# Out:
# Note
# Save extra with combo offers      348
# Bank Offer                        292
# EOSS Special Deal                 140
# Lowest Price in 30 days            43
# Lowest price since launch          40
# Daily Saver                        32
# Only few left                      19
# Lowest price in the year           12
# Only 1 left                         7
# Only 2 left                         5
# Hot Deal                            5
# Only 5 left                         4
# Upto ?33,000 Off on Exchange        2
# Lowest Price in 15 days             2
# No Cost EMI from ?66,650/month      2
# Only 3 left                         1
# Only 4 left                         1
# Upto ?20,000 Off on Exchange        1
# No Cost EMI from ?48,317/month      1
# No Cost EMI from ?58,317/month      1
# Name: count, dtype: int64

# %%
df['Company'] = df['Title'].apply(lambda x: x.split(' ')[0])

# %%
df.columns
# Out:
# Index(['Title', 'Processor', 'Ram', 'OS', 'Storage', 'Display', 'Warranty',
#        'Discount Price', 'Original Price', 'Delivery', 'Note', 'Offer',
#        'Reviews', 'Company'],
#       dtype='object')

# %%
df['Processor'] = df['Processor'].apply(lambda x: x.replace('Processor:','').strip())
df['ProcessorC'] = df['Processor'].apply(lambda x: x.split(' ')[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             960 non-null    object
#  1   Processor         960 non-null    object
#  2   Ram               960 non-null    object
#  3   OS                960 non-null    object
#  4   Storage           895 non-null    object
#  5   Display           959 non-null    object
#  6   Warranty          915 non-null    object
#  7   Discount Price    960 non-null    float64
#  8   Original Price    960 non-null    float64
#  9   Delivery          958 non-null    object
#  10  Note              958 non-null    object
#  11  Offer             666 non-null    object
#  12  Reviews           795 non-null    object
#  13  Company           960 non-null    object
#  14  ProcessorCompany  960 non-null    object
#  15  ProcessorC        960 non-null    object
# ...

# %%
df[(df['OS']=='8 GB DDR3 RAM') | (df['OS']=='8 GB DDR4 RAM')]
# Out:
#                                                  Title  \
# 373  ASUS ROG Intel Core i7 7th Gen 7700HQ - (8 GB/...
# 577  Acer Spin 7 Intel Core i7 7th Gen 7Y75 - (8 GB...
# 607  Acer Spin 7 Intel Core i7 7th Gen 7Y75 - (8 GB...
#
#                                              Processor  \
# 373  Pre-installed Genuine Windows 10 Operating Sys...
# 577  Pre-installed Genuine Windows 10 Operating Sys...
# 607  Pre-installed Genuine Windows 10 Operating Sys...
#
#                                    Ram             OS Storage  \
# 373  Intel Core i7 Processor (7th Gen)  8 GB DDR4 RAM     NaN
# 577  Intel Core i7 Processor (7th Gen)  8 GB DDR3 RAM     NaN
# 607  Intel Core i7 Processor (7th Gen)  8 GB DDR3 RAM     NaN
#
#                  Display                                Warranty  \
# 373  1 TB HDD|256 GB SSD            39.62 cm (15.6 inch) Display
# 577           256 GB SSD  35.56 cm (14 inch) Touchscreen Display
# 607           256 GB SSD  35.56 cm (14 inch) Touchscreen Display
#
# ...

# %% [markdown]
# #### Manual Work

# %%
# 373, 577, 607
df.loc[373,'Processor'] = 'Intel Core i7 Processor (7th Gen)'
df.loc[373,'OS'] = 'Windows 10'
df.loc[373,'Ram'] = '8 GB DDR4 RAM'
df.loc[373,'Storage'] = '1 TB HDD|256 GB SSD'
df.loc[373,'Display'] = '39.62 cm (15.6 inch) Display'
df.loc[373,'Warranty'] = np.nan

# %%
df.loc[577,'Processor'] = 'Intel Core i7 Processor (7th Gen)'
df.loc[577,'OS'] = 'Windows 10'
df.loc[577,'Ram'] = '8 GB DDR3 RAM'
df.loc[577,'Storage'] = '256 GB SSD'
df.loc[577,'Display'] = '35.56 cm (14 inch) Touchscreen Display'
df.loc[577,'Warranty'] = np.nan

# %%
df.loc[607,'Processor'] = 'Intel Core i7 Processor (7th Gen)'
df.loc[607,'OS'] = 'Windows 10'
df.loc[607,'Ram'] = '8 GB DDR3 RAM'
df.loc[607,'Storage'] = '256 GB SSD'
df.loc[607,'Display'] = '35.56 cm (14 inch) Touchscreen Display'
df.loc[607,'Warranty'] = np.nan

# %%
df.loc[[373,577,607]]
# Out:
#                                                  Title  \
# 373  ASUS ROG Intel Core i7 7th Gen 7700HQ - (8 GB/...
# 577  Acer Spin 7 Intel Core i7 7th Gen 7Y75 - (8 GB...
# 607  Acer Spin 7 Intel Core i7 7th Gen 7Y75 - (8 GB...
#
#                              Processor            Ram          OS  \
# 373  Intel Core i7 Processor (7th Gen)  8 GB DDR4 RAM  Windows 10
# 577  Intel Core i7 Processor (7th Gen)  8 GB DDR3 RAM  Windows 10
# 607  Intel Core i7 Processor (7th Gen)  8 GB DDR3 RAM  Windows 10
#
#                  Storage                                 Display Warranty  \
# 373  1 TB HDD|256 GB SSD            39.62 cm (15.6 inch) Display      NaN
# 577           256 GB SSD  35.56 cm (14 inch) Touchscreen Display      NaN
# 607           256 GB SSD  35.56 cm (14 inch) Touchscreen Display      NaN
#
#      Discount Price  Original Price       Delivery  \
# 373        107079.0        146490.0  Free delivery
# 577         87207.0        124900.0  Free delivery
# ...

# %%
df['OS'].value_counts()
# Out:
# OS
# Windows 11                                                                  774
# Windows 10                                                                   65
# Windows 11 Home                                                              33
# Mac OS                                                                       30
# Chrome                                                                       24
# DOS                                                                          16
# Linux/Ubuntu                                                                  4
# Graphics & Keyboard: Integrated & Standard Keyboard                           3
# 16 GB DDR4 RAM                                                                3
# 32 bit Windows 11                                                             3
# Graphics & Keyboard: NVIDIAGeForceMX550 (2GB GDDR6) + Fingerprint Reader      2
# Graphics & Keyboard: Integrated & Backlit Keyboard + Fingerprint Reader       2
# ...

# %%
df[(df['OS']=='Graphics & Keyboard: NVIDIAGeForceMX550 (2GB GDDR6) + Fingerprint Reader') | (df['OS']=='Graphics & Keyboard: Integrated & Backlit Keyboard + Fingerprint Reader')]
# Out:
#                                                  Title  \
# 118  DELL Inspiron Intel Core i7 12th Gen 1255U - (...
# 165  DELL Inspiron Intel Core i7 12th Gen 1255U - (...
# 329  DELL Intel Core i5 12th Gen 1235U - (8 GB/512 ...
# 494  DELL Inspiron Intel Core i5 12th Gen 1235U - (...
#
#                                              Processor  \
# 118  Intel i7-1255U (Base- 3.50 GHz & Turbo up to 4...
# 165  Intel i7-1255U (Base- 3.50 GHz & Turbo up to 4...
# 329  Intel i5-1235U (Base- 3.30 GHz & Turbo up to 4...
# 494  Intel i5-1235U (Base- 3.30 GHz & Turbo up to 4...
#
#                                       Ram  \
# 118  RAM & Storage: 16GB DDR4 & 512GB SSD
# 165  RAM & Storage: 16GB DDR4 & 512GB SSD
# 329   RAM & Storage: 8GB DDR4 & 512GB SSD
# 494  RAM & Storage: 16GB DDR4 & 512GB SSD
#
#                                                     OS Storage  \
# 118  Graphics & Keyboard: NVIDIAGeForceMX550 (2GB G...     NaN
# ...

# %%
def edit_value(index,processor,ram,os,storage,display,warranty):
    df.loc[index,'Processor'] = processor
    df.loc[index,'Ram'] = ram
    df.loc[index,'OS'] = os
    df.loc[index,'Storage'] = storage
    df.loc[index,'Display'] = display
    df.loc[index,'Warranty'] = warranty

# %%
index = [118,165,329,494]
processor = ['Intel Core i7 Processor (12th Gen)','Intel Core i7 Processor (12th Gen)','Intel Core i5 Processor (12th Gen)','Intel Core i5 Processor (12th Gen)']
ram = ['16GB DDR4','16GB DDR4','8GB DDR4','16GB DDR4']
os = ['Windows 10','Windows 10','Windows 10','Windows 10']
storage = ['512 GB SSD','512 GB SSD','512 GB SSD','512 GB SSD']
display = [np.nan,np.nan,np.nan,np.nan]
warranty = [np.nan,np.nan,np.nan,np.nan]

# %%
for i,p,r,o,s,d,w in zip(index,processor,ram,os,storage,display,warranty):
    edit_value(i,p,r,o,s,d,w)

# %%
df.loc[index].Title
# Out:
# 118    DELL Inspiron Intel Core i7 12th Gen 1255U - (...
# 165    DELL Inspiron Intel Core i7 12th Gen 1255U - (...
# 329    DELL Intel Core i5 12th Gen 1235U - (8 GB/512 ...
# 494    DELL Inspiron Intel Core i5 12th Gen 1235U - (...
# Name: Title, dtype: object

# %%
df['Reviews'] = df['Reviews'].fillna('99').apply(lambda x: x[0]).astype(int).replace(9,np.nan)

# %%
df['Reviews'].value_counts()
# Out:
# Reviews
# 4.0    635
# 3.0    132
# 5.0     22
# 2.0      5
# 1.0      1
# Name: count, dtype: int64

# %%
df['Reviews'].mean()
# Out:
# 3.8452830188679243

# %%
df['Reviews'].fillna(3,inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13264\3903337827.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Reviews'].fillna(3,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             960 non-null    object
#  1   Processor         960 non-null    object
#  2   Ram               960 non-null    object
#  3   OS                960 non-null    object
#  4   Storage           902 non-null    object
#  5   Display           955 non-null    object
#  6   Warranty          908 non-null    object
#  7   Discount Price    960 non-null    float64
#  8   Original Price    960 non-null    float64
#  9   Delivery          958 non-null    object
#  10  Note              958 non-null    object
#  11  Offer             666 non-null    object
#  12  Reviews           960 non-null    float64
#  13  Company           960 non-null    object
#  14  ProcessorCompany  960 non-null    object
#  15  ProcessorC        960 non-null    object
# ...

# %%
# Function to extract storage information
def extract_storage(title):
    if '- (' in title:
        return title.split('- ')[1].split('/')[1].strip()
    else:
        return None

# Fill null values in Storage column
df.loc[df['Storage'].isna(), 'Storage'] = df[df['Storage'].isna()]['Title'].apply(extract_storage)

# %%
df[df['Storage'].isna()]
# Out:
# Empty DataFrame
# Columns: [Title, Processor, Ram, OS, Storage, Display, Warranty, Discount Price, Original Price, Delivery, Note, Offer, Reviews, Company, ProcessorCompany, ProcessorC]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             960 non-null    object
#  1   Processor         960 non-null    object
#  2   Ram               960 non-null    object
#  3   OS                960 non-null    object
#  4   Storage           960 non-null    object
#  5   Display           955 non-null    object
#  6   Warranty          908 non-null    object
#  7   Discount Price    960 non-null    float64
#  8   Original Price    960 non-null    float64
#  9   Delivery          958 non-null    object
#  10  Note              958 non-null    object
#  11  Offer             666 non-null    object
#  12  Reviews           960 non-null    float64
#  13  Company           960 non-null    object
#  14  ProcessorCompany  960 non-null    object
#  15  ProcessorC        960 non-null    object
# ...

# %%
for i in df[df['Display'].isna()].Title:
    print(i)
# Out:
# DELL Inspiron Intel Core i7 12th Gen 1255U - (16 GB/512 GB SSD/Windows 11 Home/2 GB Graphics) Inspiron...
# DELL Inspiron Intel Core i7 12th Gen 1255U - (16 GB/512 GB SSD/Windows 11 Home/2 GB Graphics) Inspiron...
# DELL Intel Core i5 12th Gen 1235U - (8 GB/512 GB SSD/Windows 11 Home) New Inspiron 14 2-in-1 2 in 1 La...
# DELL Inspiron Intel Core i5 12th Gen 1235U - (16 GB/512 GB SSD/Windows 11 Home) Inspiron 7420 2 in 1 L...
# Lenovo Intel Intel Celeron Dual Core 4th Gen N4020 - (4 GB/64 GB EMMC Storage/Chrome OS) 14IGL05 Chrom...

# %%
df[df['Note'].isna()]
# Out:
#                                                  Title  \
# 249  Infinix GT Book Intel Core i5 12th Gen 12450H ...
# 290  DELL Inspiron Intel Core i5 11th Gen 11320H - ...
#
#                               Processor               Ram          OS  \
# 249  Intel Core i5 Processor (12th Gen)  16 GB LPDDR5 RAM  Windows 11
# 290  Intel Core i5 Processor (11th Gen)    16 GB DDR4 RAM  Windows 11
#
#         Storage                       Display                Warranty  \
# 249  512 GB SSD    40.64 cm (16 inch) Display          Control Center
# 290  512 GB SSD  39.62 cm (15.6 Inch) Display  1 Year Onsite Warranty
#
#      Discount Price  Original Price Delivery Note Offer  Reviews  Company  \
# 249         64990.0         99990.0      NaN  NaN   NaN      4.0  Infinix
# 290         36607.0         90783.0      NaN  NaN   NaN      4.0     DELL
#
#     ProcessorCompany ProcessorC
# 249            Intel      Intel
# 290            Intel      Intel

# %%
df.sample(10)
# Out:
#                                                  Title  \
# 143  ASUS Vivobook Go 15 (2023) AMD Ryzen 3 Quad Co...
# 631  ASUS Chromebook Plus (2023) Intel Core i3 12th...
# 606  Lenovo ThinkPad E14 AMD Ryzen 5 Hexa Core 7530...
# 801  Acer Aspire 5 Intel Core i5 12th Gen 1235U - (...
# 368  Acer Intel Core i7 13th Gen - (16 GB/512 GB SS...
# 107  Lenovo IdeaPad Flex 5 AMD Ryzen 7 Octa Core 57...
# 193  Lenovo LOQ Intel Core i5 12th Gen 12450H - (16...
# 480  AXL Intel Celeron Dual Core 9th Gen - (4 GB/25...
# 887  Acer Aspire 3 Intel Core i3 12th Gen 1215U - (...
# 928  MSI Prestige 13 Evo Intel Core i7 13th Gen 136...
#
#                                        Processor                Ram  \
# 143              AMD Ryzen 3 Quad Core Processor    8 GB LPDDR5 RAM
# 631           Intel Core i3 Processor (12th Gen)    8 GB LPDDR5 RAM
# 606              AMD Ryzen 5 Hexa Core Processor     16 GB DDR4 RAM
# 801           Intel Core i5 Processor (12th Gen)      8 GB DDR4 RAM
# ...

# %%
df.to_csv('cleaned_data.csv',index=False)
